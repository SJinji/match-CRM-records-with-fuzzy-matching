# %% [markdown]
# <a href="https://colab.research.google.com/github/SJinji/match-tables-with-fuzzy-matching/blob/main/Reveal_Tech_Case_Jinji.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install fuzzymatcher
# Out:
# Requirement already satisfied: fuzzymatcher in /usr/local/lib/python3.10/dist-packages (0.0.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from fuzzymatcher) (1.5.3)
# Requirement already satisfied: metaphone in /usr/local/lib/python3.10/dist-packages (from fuzzymatcher) (0.6)
# Requirement already satisfied: python-Levenshtein in /usr/local/lib/python3.10/dist-packages (from fuzzymatcher) (0.21.1)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.10/dist-packages (from fuzzymatcher) (3.1.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from fuzzymatcher) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->fuzzymatcher) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->fuzzymatcher) (1.22.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->fuzzymatcher) (1.16.0)
# Requirement already satisfied: Levenshtein==0.21.1 in /usr/local/lib/python3.10/dist-packages (from python-Levenshtein->fuzzymatcher) (0.21.1)

# %%
! pip install recordlinkage
# Out:
# Requirement already satisfied: recordlinkage in /usr/local/lib/python3.10/dist-packages (0.16)
# Requirement already satisfied: jellyfish>=1 in /usr/local/lib/python3.10/dist-packages (from recordlinkage) (1.0.0)
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.10/dist-packages (from recordlinkage) (1.22.4)
# Requirement already satisfied: pandas<3,>=1 in /usr/local/lib/python3.10/dist-packages (from recordlinkage) (1.5.3)
# Requirement already satisfied: scipy>=1 in /usr/local/lib/python3.10/dist-packages (from recordlinkage) (1.10.1)
# Requirement already satisfied: scikit-learn>=1 in /usr/local/lib/python3.10/dist-packages (from recordlinkage) (1.2.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from recordlinkage) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1->recordlinkage) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1->recordlinkage) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1->recordlinkage) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas<3,>=1->recordlinkage) (1.16.0)

# %%
import pandas as pd
import numpy as np
import fuzzymatcher

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data Preprocessing

# %%
# Load the datasets into pandas DataFrames
dataset_a = pd.read_csv('dataset_A.csv', header=None)
dataset_b = pd.read_csv('dataset_B.csv', header=None)

# %%
# Remove column 3 from both datasets
dataset_a.drop(3, axis=1, inplace=True)
dataset_b.drop(3, axis=1, inplace=True)

# Add column names to datasets A and B
column_names = ['id', 'company_name', 'website', 'phone_number', 'address', 'postcode', 'region', 'country']
dataset_a.columns = column_names
dataset_b.columns = column_names

# %%
# Function to preprocess the columns
def preprocess_columns(df):
    # Convert company names to lowercase and replace "'" with whitespace
    df['company_name'] = df['company_name'].str.lower().str.replace("'", ' ')

    # Remove prefixes "http://" and "www." from the website column
    df['website'] = df['website'].str.replace(r'^https?://', '', case=False)
    df['website'] = df['website'].str.replace(r'^www\.', '', case=False)
    # Remove trailing slashes from the website column
    df['website'] = df['website'].str.rstrip('/')

    # Remove leading zeros from phone numbers
    df['phone_number'] = df['phone_number'].str.replace(r'\.', '')
    df['phone_number'] = df['phone_number'].str.replace(r'^\+?33|^\+?0*', '').str.replace(r'\s', '')

    # Remove commas from addresses
    df['address'] = df['address'].str.replace(',', '').str.lower()

    # Remove ".0" from postcode and convert it to an integer
    df['postcode'] = df['postcode'].astype(str).str.replace(r'\.0$', '')
    df['postcode'] = pd.to_numeric(df['postcode'], errors='coerce')

    # Convert region names to lowercase
    df['region'] = df['region'].str.lower()

    # Convert country names to lowercase
    df['country'] = df['country'].str.lower()

    # Remove '-' from specified columns
    columns_to_remove_dash = ['company_name', 'address', 'region', 'country']
    for col in columns_to_remove_dash:
        df[col] = df[col].str.replace('-', '').str.strip()

    # Remove duplicates from the DataFrame
    df.drop_duplicates(inplace=True)

    return df

# %%
# Preprocess datasets
preprocess_columns(dataset_a)
preprocess_columns(dataset_b)
# Out:
#           id                        company_name            website  \
# 0         23  groupe bertrand  angelina (parent)                NaN
# 1         36                   sushi shop amiens                NaN
# 2         61              sushi shop vieux lille                NaN
# 3         87                         ibis angers                NaN
# 4         98                        le christine                NaN
# ...      ...                                 ...                ...
# 8731  424609           mercure lisieux normandie    accorhotels.com
# 8732  424650                        inmac wstore    inmacwstore.com
# 8733  424662                      ma french bank    mafrenchbank.fr
# 8734  424857               hôtel ibis brignolles    accorhotels.com
# 8735  424904                       groupe butard  groupe-butard.com
#
#      phone_number             address  postcode                 region country
# 0             NaN                 NaN       NaN                    NaN  france
# 1             NaN                 NaN   80000.0                    NaN  france
# 2             NaN                 NaN   59000.0                    NaN  france
# 3             NaN                 NaN   41000.0                    NaN  france
# 4       140517164                 NaN   75006.0                    NaN  france
# ...           ...                 ...       ...                    ...     ...
# 8731    231611717                 NaN   14100.0                    NaN     NaN
# 8732          NaN                 NaN       NaN                    NaN     NaN
# 8733          NaN   115 rue de sèvres   75006.0  paris6earrondissement  france
# 8734    494691929                 NaN   83170.0                    NaN     NaN
# 8735          NaN  allée de longchamp   75116.0                  paris  france
#
# [8736 rows x 8 columns]

# %%
dataset_a.columns = [f'{col}_a' for col in column_names]
dataset_b.columns = [f'{col}_b' for col in column_names]

# %% [markdown]
# # Fuzzy Matching

# %% [markdown]
# This package leverages sqlite’s full text search capability to try to match records in two different DataFrames.

# %%
# Find common ids based on id, website, or phone_number
common_ids_id = dataset_a.merge(dataset_b, left_on='id_a', right_on='id_b', how='inner')

# Filter out rows with non-null values in the "website_a" column
dataset_a_website_notnull = dataset_a.dropna(subset=['website_a'])
common_ids_website = dataset_a_website_notnull.merge(dataset_b, left_on='website_a', right_on='website_b', how='inner')

# Filter out rows with non-null values in the "phone_number_a" column
dataset_a_phone_notnull = dataset_a.dropna(subset=['phone_number_a'])
common_ids_phone = dataset_a_phone_notnull.merge(dataset_b, left_on='phone_number_a', right_on='phone_number_b', how='inner')

# Concatenate all common_ids based on different criteria to get unique common ids
common_ids = pd.concat([common_ids_id, common_ids_website, common_ids_phone]).drop_duplicates()

# Exclude common_ids from dataset_a and dataset_b to get the unmatched rows
dataset_a_only = dataset_a[~dataset_a['id_a'].isin(common_ids['id_a'])]
dataset_b_only = dataset_b[~dataset_b['id_b'].isin(common_ids['id_b'])]

# %%
# Fill NaN values with empty strings in dataset_a
dataset_a_only.fillna('', inplace=True)
# Fill NaN values with empty strings in dataset_b
dataset_b_only.fillna('', inplace=True)

# %%
left_on = ["company_name_a",'website_a','phone_number_a',"address_a",'postcode_a','region_a', 'country_a']
right_on = ["company_name_b",'website_b','phone_number_b',"address_b",'postcode_b','region_b', 'country_b']

# %%
# Running time: 1min
matched_results = fuzzymatcher.fuzzy_left_join(dataset_a_only,
                                            dataset_b_only,
                                            left_on,
                                            right_on,
                                            left_id_col='id_a',
                                            right_id_col='id_b')

# %%
cols = [
    "best_match_score",'id_a',"company_name_a",'website_a','phone_number_a',"address_a",'postcode_a','region_a','country_a',
    'id_b',"company_name_b",'website_b','phone_number_b',"address_b",'postcode_b','region_b','country_b'
]

# Filter out rows with NaN in 'best_match_score' column
matched_results = matched_results[matched_results['best_match_score'].notna()]

# Convert 'id_b' to integer data type
matched_results['id_b'] = matched_results['id_b'].astype(int)


# Sort the results by best_match_score in descending order
matched_results[cols].sort_values(by=['best_match_score'], ascending=False)
# Out:
#         best_match_score    id_a                 company_name_a  \
# 164105          2.446235  250279             l unionl ardennais
# 26734           1.921578   26832           west suffolk college
# 209681          1.816910  379181              talentia software
# 58320           1.814262   53405               sonovision group
# 129504          1.788510  173694     allianz worldwide partners
# ...                  ...     ...                            ...
# 175302         -1.860505  266560  4 pieds  groupe confort decor
# 138123         -1.890183  180260                barry callebaut
# 152952         -2.155894  234585            crédit mutuel océan
# 87387          -2.386287   81158                  adversitement
# 88861          -2.542007   82121        groupe edition lingerie
#
#                                                 website_a phone_number_a  \
# 164105                                          lunion.fr
# 26734                            westsuffolkcollege.ac.uk   441284701301
# 209681                              talentia-software.com
# 58320                          relay1.sonovisiongroup.com
# 129504              allianz-worldwide-partners.fr/contact
# ...                                                   ...            ...
# 175302                                        4-pieds.com      299055760
# 138123
# 152952                  creditmutuel.fr/cmo/fr/index.html      251475300
# 87387   adversitement.fr, https://twitter.com/sgendrel...  (207)060-2814
# 88861   editionlingerie.de, http://www.orcanta.fr, htt...  (212)653-9260
#
#                                                 address_a postcode_a  \
# 164105                          21 rue des frères gilbert     7800.0
# 26734                                       out risbygate
# 209681                                   21 rue lavoisier    92500.0
# 58320                          160 avenue aristide briand    92220.0
# 129504                                    7 rue dora maar    93400.0
# ...                                                   ...        ...
# 175302  parc d'activités les grandes landes 9 rue blai...    35580.0
# 138123
# 152952            46 rue du port boyer b.p. 92636 cedex 3    75436.0
# 87387                                   18 rue de turbigo
# 88861                                   8 rue de provigny    94230.0
#
#                 region_a       country_a    id_b             company_name_b  \
# 164105               ath         belgium   70446         l unionl ardennais
# 26734    bury st edmunds  united kingdom  200405       west suffolk college
# 209681   rueil malmaison          france  385229          talentia software
# 58320            bagneux          france  198770           sonovision group
# 129504         saintouen          france  105136           allianz partners
# ...                  ...             ...     ...                        ...
# 175302                            france  373629                    4 pieds
# 138123                                    310535  metro cash & carry france
# 152952  la roche sur yon          france  175950        credit mutuel anjou
# 87387              paris          france  251765                  printemps
# 88861             cachan          france   80777                  allopneus
#
#                                       website_b phone_number_b  \
# 164105                        journal-lunion.fr
# 26734                                 wsc.ac.uk     1284716333
# 209681                     talenta-software.com
# 58320                       sonovisiongroup.com
# 129504            allianz-worldwide-partners.fr      153255325
# ...                                         ...            ...
# 175302
# 138123
# 152952
# 87387                              printemps.fr
# 88861   ALLOPNEUS.COM, http://www.allopneus.com
#
#                                           address_b postcode_b  \
# 164105                    21 rue des frères gilbert     7800.0
# 26734                                 out risbygate
# 209681                             21 rue lavoisier    92500.0
# 58320                    160 avenue aristide briand    92220.0
# 129504                              7 rue dora maar    93400.0
# ...                                             ...        ...
# 175302
# 138123  za du petit nanterre  5 rue des grands pr�s    92024.0
# 152952
# 87387                           102 rue de provence    75009.0
# 88861
#
#                region_b       country_b
# 164105              ath         belgium
# 26734   bury st edmunds  united kingdom
# 209681  rueil malmaison          france
# 58320           bagneux          france
# 129504        saintouen          france
# ...                 ...             ...
# 175302
# 138123   nanterre cedex          france
# 152952
# 87387             paris          france
# 88861                            france
#
# [2029 rows x 17 columns]

# %%
matched_results[cols].query("best_match_score <= -.01").sort_values(
    by=['best_match_score'], ascending=False).head(5)
# Out:
#         best_match_score    id_a        company_name_a  website_a  \
# 5749           -0.011734    8211         bureau vallée
# 200138         -0.011734  349794         bureau vallée
# 38105          -0.013759   38655                 segef  segef.com
# 110203         -0.013946  105247               cofares
# 98266          -0.014239   93172  transport for london
#
#        phone_number_a         address_a postcode_a region_a country_a    id_b  \
# 5749                                                                   317667
# 200138                                                                 317667
# 38105       534314021  2 rue kellermann    59100.0  roubaix    france  191579
# 110203                                                          spain  104719
# 98266                                                                  180585
#
#                company_name_b       website_b phone_number_b  \
# 5749    bureau veritas france
# 200138  bureau veritas france
# 38105                 ovh ltd  deftagroup.com
# 110203               vodafone
# 98266        alstom transport
#
#                address_b postcode_b region_b country_b
# 5749
# 200138
# 38105   2 rue kellermann    59100.0  roubaix    france
# 110203                                           spain
# 98266

# %%
# Filter matched_results based on best_match_score >= -0.01
filtered_matched_results = matched_results[matched_results['best_match_score'] >= -0.01]

# Concatenate filtered_matched_results with common_ids
final_result = pd.concat([filtered_matched_results, common_ids], axis=0)

# Keep only the desired columns
final_result = final_result[['id_a', 'company_name_a', 'id_b', 'company_name_b', 'best_match_score']]

# Save the result as a CSV file
final_result.to_csv('matched_results.csv', index=False)

# %%
final_result
# Out:
#         id_a             company_name_a    id_b            company_name_b  \
# 0        186       dupont café (parent)  136916               dupont café
# 89       259      tempête sous un crâne  144638     tempète sous un crâne
# 971      871             sushi juliette  124451            sushi juliette
# 972      902              la dolce vita  119310             la dolce vita
# 1331    1143  yogurt factory la défense    6067  pullman paris la défense
# ...      ...                        ...     ...                       ...
# 6277  405677    serge blanco groupe lby   82680              serge blanco
# 6281  406876               sport thieme   82629               sportthieme
# 6284  412347                  adidas us  239082              adidas group
# 6287  412937                    repetto  241703             repetto paris
# 6295  422060                      accor  104972               accorhotels
#
#       best_match_score
# 0             0.158676
# 89            0.349689
# 971           0.284954
# 972           0.607392
# 1331          0.029794
# ...                ...
# 6277               NaN
# 6281               NaN
# 6284               NaN
# 6287               NaN
# 6295               NaN
#
# [20753 rows x 5 columns]
